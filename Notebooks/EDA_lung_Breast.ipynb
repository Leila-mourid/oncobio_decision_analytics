# %%
import pandas as pd

# %%
breast = pd.read_csv(r"C:\Projet_filrouge\oncobio_decision_analytics\Data\Interim\SEER Breast Cancer Dataset .csv")
lung = pd.read_csv(r"C:\Projet_filrouge\oncobio_decision_analytics\Data\Interim\survey lung cancer.csv")

breast.info()
lung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   object
#  2   Marital Status          4024 non-null   object
#  3   Unnamed: 3              0 non-null      float64
#  4   T Stage                 4024 non-null   object
#  5   N Stage                 4024 non-null   object
#  6   6th Stage               4024 non-null   object
#  7   Grade                   4024 non-null   object
#  8   A Stage                 4024 non-null   object
#  9   Tumor Size              4024 non-null   int64
#  10  Estrogen Status         4024 non-null   object
#  11  Progesterone Status     4024 non-null   object
#  12  Regional Node Examined  4024 non-null   int64
#  13  Reginol Node Positive   4024 non-null   int64
#  14  Survival Months         4024 non-null   int64
#  15  Status                  4024 non-null   object
# dtypes: float64(1), int64(5), object(10)
# memory usage: 503.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GENDER                 309 non-null    object
#  1   AGE                    309 non-null    int64
#  2   SMOKING                309 non-null    int64
#  3   YELLOW_FINGERS         309 non-null    int64
#  4   ANXIETY                309 non-null    int64
#  5   PEER_PRESSURE          309 non-null    int64
#  6   CHRONIC DISEASE        309 non-null    int64
#  7   FATIGUE                309 non-null    int64
#  8   ALLERGY                309 non-null    int64
#  9   WHEEZING               309 non-null    int64
#  10  ALCOHOL CONSUMING      309 non-null    int64
#  11  COUGHING               309 non-null    int64
#  12  SHORTNESS OF BREATH    309 non-null    int64
#  13  SWALLOWING DIFFICULTY  309 non-null    int64
#  14  CHEST PAIN             309 non-null    int64
#  15  LUNG_CANCER            309 non-null    object
# dtypes: int64(14), object(2)
# memory usage: 38.8+ KB

# %%
breast.columns
# Out:
# Index(['Age', 'Race ', 'Marital Status', 'Unnamed: 3', 'T Stage ', 'N Stage',
#        '6th Stage', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status',
#        'Progesterone Status', 'Regional Node Examined',
#        'Reginol Node Positive', 'Survival Months', 'Status'],
#       dtype='object')

# %%
lung.columns
# Out:
# Index(['GENDER', 'AGE', 'SMOKING', 'YELLOW_FINGERS', 'ANXIETY',
#        'PEER_PRESSURE', 'CHRONIC DISEASE', 'FATIGUE ', 'ALLERGY ', 'WHEEZING',
#        'ALCOHOL CONSUMING', 'COUGHING', 'SHORTNESS OF BREATH',
#        'SWALLOWING DIFFICULTY', 'CHEST PAIN', 'LUNG_CANCER'],
#       dtype='object')

# %%
lung = lung.rename(columns={
    "AGE": "Age",
    "GENDER": "Gender"
})

lung["cancer_type"] = "Lung"

# %%
import numpy as np

# Score symptomes
symptoms_cols = [
    "WHEEZING", "COUGHING", "SHORTNESS OF BREATH",
    "CHEST PAIN", "SWALLOWING DIFFICULTY"
]

lung["symptom_score"] = lung[symptoms_cols].sum(axis=1)

# Définition stade
conditions = [
    lung["symptom_score"] <= 1,
    lung["symptom_score"] == 2,
    lung["symptom_score"] == 3,
    lung["symptom_score"] >= 4
]

choices = ["I", "II", "III", "IV"]

lung["stage"] = np.select(conditions, choices)

# %%
def simulate_survival(stage):
    if stage == "I":
        return np.random.normal(60, 10)
    elif stage == "II":
        return np.random.normal(36, 8)
    elif stage == "III":
        return np.random.normal(18, 6)
    else:
        return np.random.normal(8, 3)

lung["survival_months"] = lung["stage"].apply(simulate_survival)

lung["survival_months"] = lung["survival_months"].clip(lower=1)

# %%
lung["event"] = (lung["survival_months"] < 36).astype(int)

# %%
lung["patient_id"] = range(1, len(lung)+1)

# %%
lung_clean = lung[[
    "patient_id",
    "cancer_type",
    "Age",
    "Gender",
    "stage",
    "survival_months",
    "event"
]]
lung_clean.to_csv(r"C:\Projet_filrouge\oncobio_decision_analytics\Data\Processed\lung_cancer_clean.csv", index=False)

# %%
import sys
# !{sys.executable} -m pip install -U sdv
# Out:
# Requirement already satisfied: sdv in c:\users\leila\anaconda3\lib\site-packages (1.33.1)
# Collecting sdv
#   Downloading sdv-1.34.0-py3-none-any.whl (200 kB)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (1.42.46)
# Requirement already satisfied: cloudpickle>=2.1.0 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (3.1.2)
# Requirement already satisfied: deepecho>=0.7.0 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (0.8.0)
# Requirement already satisfied: graphviz>=0.13.2 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (0.21)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (1.22.4)
# Requirement already satisfied: rdt>=1.18.2 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (1.20.0)
# Requirement already satisfied: sdmetrics>=0.21.0 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (0.27.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (1.4.2)
# Requirement already satisfied: platformdirs>=4.0 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (4.4.0)
# Requirement already satisfied: pyyaml>=6.0.1 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (6.0.3)
# Requirement already satisfied: ctgan>=0.11.1 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (0.12.0)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (1.42.46)
# Requirement already satisfied: tqdm>=4.29 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (4.64.0)
# Requirement already satisfied: copulas>=0.12.1 in c:\users\leila\anaconda3\lib\site-packages (from sdv) (0.14.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in c:\users\leila\anaconda3\lib\site-packages (from boto3<2.0.0,>=1.28->sdv) (0.16.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\leila\anaconda3\lib\site-packages (from boto3<2.0.0,>=1.28->sdv) (0.10.0)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in c:\users\leila\anaconda3\lib\site-packages (from botocore<2.0.0,>=1.31->sdv) (1.26.9)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\leila\anaconda3\lib\site-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: plotly>=5.10.0 in c:\users\leila\anaconda3\lib\site-packages (from copulas>=0.12.1->sdv) (6.5.2)
# Requirement already satisfied: scipy>=1.7.3 in c:\users\leila\anaconda3\lib\site-packages (from copulas>=0.12.1->sdv) (1.7.3)
# Requirement already satisfied: torch>=1.13.0 in c:\users\leila\anaconda3\lib\site-packages (from ctgan>=0.11.1->sdv) (2.8.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\leila\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->sdv) (2021.3)
# Requirement already satisfied: packaging in c:\users\leila\anaconda3\lib\site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (21.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\leila\anaconda3\lib\site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (2.16.0)
# Requirement already satisfied: six>=1.5 in c:\users\leila\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.16.0)
# Requirement already satisfied: Faker!=37.11.0,>=17 in c:\users\leila\anaconda3\lib\site-packages (from rdt>=1.18.2->sdv) (37.12.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\leila\anaconda3\lib\site-packages (from rdt>=1.18.2->sdv) (1.0.2)
# Requirement already satisfied: tzdata in c:\users\leila\anaconda3\lib\site-packages (from Faker!=37.11.0,>=17->rdt>=1.18.2->sdv) (2025.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\leila\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->rdt>=1.18.2->sdv) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\leila\anaconda3\lib\site-packages (from scikit-learn>=1.0.2->rdt>=1.18.2->sdv) (1.1.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\leila\anaconda3\lib\site-packages (from torch>=1.13.0->ctgan>=0.11.1->sdv) (4.15.0)
# Requirement already satisfied: filelock in c:\users\leila\anaconda3\lib\site-packages (from torch>=1.13.0->ctgan>=0.11.1->sdv) (3.6.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\leila\anaconda3\lib\site-packages (from torch>=1.13.0->ctgan>=0.11.1->sdv) (1.14.0)
# Requirement already satisfied: fsspec in c:\users\leila\anaconda3\lib\site-packages (from torch>=1.13.0->ctgan>=0.11.1->sdv) (2022.2.0)
# Requirement already satisfied: networkx in c:\users\leila\anaconda3\lib\site-packages (from torch>=1.13.0->ctgan>=0.11.1->sdv) (2.7.1)
# Requirement already satisfied: jinja2 in c:\users\leila\anaconda3\lib\site-packages (from torch>=1.13.0->ctgan>=0.11.1->sdv) (2.11.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\leila\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.13.0->ctgan>=0.11.1->sdv) (1.2.1)
# Requirement already satisfied: colorama in c:\users\leila\anaconda3\lib\site-packages (from tqdm>=4.29->sdv) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\leila\anaconda3\lib\site-packages (from jinja2->torch>=1.13.0->ctgan>=0.11.1->sdv) (2.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\leila\anaconda3\lib\site-packages (from packaging->plotly>=5.10.0->copulas>=0.12.1->sdv) (3.0.4)
# Installing collected packages: sdv
#   Attempting uninstall: sdv
#     Found existing installation: sdv 1.33.1
#     Uninstalling sdv-1.33.1:
#       Successfully uninstalled sdv-1.33.1
# Successfully installed sdv-1.34.0

# %%
import os
import numpy as np
import pandas as pd

from sdv.metadata import SingleTableMetadata
from sdv.single_table import GaussianCopulaSynthesizer

# 1) Charger le dataset réel (CSV conseillé)
path = r"C:\Projet_filrouge\oncobio_decision_analytics\Data\Interim\lung_cancer.xls"
lung_real = pd.read_csv(path)

# 2) Nettoyage minimal
lung_real = lung_real.dropna(axis=1, how="all").copy()
lung_real.columns = [c.strip().replace(" ", "_") for c in lung_real.columns]

# 3) Identifier colonnes clés 
# time (survie)
time_col = next((c for c in lung_real.columns if c.lower() in ["time", "survival_time", "survival_months", "survtime"]), None)
# event/status (décès vs censuré)
event_col = next((c for c in lung_real.columns if c.lower() in ["status", "event", "cens", "censored", "death"]), None)

print("time_col =", time_col)
print("event_col =", event_col)

# 4) Metadata auto
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(lung_real)

# Forcer event/sex en catégoriel si détecté en numérique 
for c in lung_real.columns:
    if c.lower() in ["sex", "gender", "status", "event", "cens", "censored", "lung_cancer"]:
        metadata.update_column(c, sdtype="categorical")

# 5) Fit SDV (sans constraints)
synth = GaussianCopulaSynthesizer(
    metadata,
    enforce_min_max_values=True,
    enforce_rounding=True
)

synth.fit(lung_real)

# 6) Générer 1000 lignes synthétiques
lung_synth = synth.sample(num_rows=1000)

# 7) Post-traitement contraintes (safe)
if time_col and time_col in lung_synth.columns:
    lung_synth[time_col] = pd.to_numeric(lung_synth[time_col], errors="coerce").fillna(1)
    lung_synth[time_col] = lung_synth[time_col].round().clip(lower=1)

if event_col and event_col in lung_synth.columns:
    # Si event doit être {0,1}
    lung_synth[event_col] = pd.to_numeric(lung_synth[event_col], errors="coerce")
    # si déjà 0/1 ok, sinon on “binarise”
    lung_synth[event_col] = (lung_synth[event_col].fillna(0) >= 1).astype(int)

# 8) Marquer synth vs réel + concat (optionnel)
lung_real["is_synthetic"] = 0
lung_synth["is_synthetic"] = 1
lung_all = pd.concat([lung_real, lung_synth], ignore_index=True)

# 9) Export
out_path = r"C:\Projet_filrouge\oncobio_decision_analytics\Data\Processed\ncctg_lung_1000_sdv.csv"
os.makedirs(os.path.dirname(out_path), exist_ok=True)
lung_all.to_csv(out_path, index=False)

print("Saved:", out_path, "shape:", lung_all.shape)
lung_all.head()
# Out:
# time_col = TIME
# event_col = None
# c:\Users\leila\anaconda3\lib\site-packages\sdv\single_table\base.py:168: FutureWarning:
#
# The 'SingleTableMetadata' is deprecated. Please use the new 'Metadata' class for synthesizers.
#
# c:\Users\leila\anaconda3\lib\site-packages\sdv\single_table\base.py:134: UserWarning:
#
# We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# Saved: C:\Projet_filrouge\oncobio_decision_analytics\Data\Processed\ncctg_lung_1000_sdv.csv shape: (1456, 9)
#    ID  TIME  Y  age sex  ecog  karnoPH  karnoPAT  is_synthetic
# 0   1     0  0   74   M     1       90       100             0
# 1   1   306  1   74   M     1       90       100             0
# 2   2     0  0   68   M     0       90        90             0
# 3   2   455  1   68   M     0       90        90             0
# 4   3     0  0   56   M     0       90        90             0

# %%
# Compare distributions sur quelques colonnes
num_cols = lung_real.select_dtypes(include=[np.number]).columns.tolist()

comp = pd.DataFrame({
    "real_mean": lung_real[num_cols].mean(numeric_only=True),
    "synth_mean": lung_synth[num_cols].mean(numeric_only=True),
    "real_median": lung_real[num_cols].median(numeric_only=True),
    "synth_median": lung_synth[num_cols].median(numeric_only=True)
}).round(2)

comp
# Out:
#               real_mean  synth_mean  real_median  synth_median
# ID               114.50      114.48        114.5         114.0
# TIME             152.62       62.54          2.5           5.0
# Y                  0.36        0.41          0.0           0.0
# age               62.45       62.72         63.0          63.0
# ecog               0.95        1.02          1.0           1.0
# karnoPH           81.93       81.47         80.0          80.0
# karnoPAT          79.96       78.89         80.0          80.0
# is_synthetic       0.00        1.00          0.0           1.0

# %%
from sdv.evaluation.single_table import evaluate_quality

report = evaluate_quality(
    real_data=lung_real.drop(columns=["is_synthetic"], errors="ignore"),
    synthetic_data=lung_synth.drop(columns=["is_synthetic"], errors="ignore"),
    metadata=metadata
)
report.get_score()
# Out:
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 8/8 [00:00<00:00, 143.41it/s]|
# Column Shapes Score: 89.42%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 28/28 [00:00<00:00, 107.96it/s]|
# Column Pair Trends Score: 70.5%
#
# Overall Score (Average): 79.96%
# 0.7996080827067669

# %%
print(lung_real.columns.tolist())
print(lung_real.head(3))
# Out:
# ['ID', 'TIME', 'Y', 'age', 'sex', 'ecog', 'karnoPH', 'karnoPAT', 'is_synthetic']
#    ID  TIME  Y  age sex  ecog  karnoPH  karnoPAT  is_synthetic
# 0   1     0  0   74   M     1       90       100             0
# 1   1   306  1   74   M     1       90       100             0
# 2   2     0  0   68   M     0       90        90             0
